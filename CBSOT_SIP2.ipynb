# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset =load_dataset("CShorten/ML-ArXiv-Papers",split='train')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
print(dataset)
# Out:
# Dataset({
#     features: ['Unnamed: 0.1', 'Unnamed: 0', 'title', 'abstract'],
#     num_rows: 117592
# })

# %%
dataset[0]
# Out:
# {'Unnamed: 0.1': 0,
#  'Unnamed: 0': 0.0,
#  'title': 'Learning from compressed observations',
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(dataset)
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  \
# 0                  0         0.0
# 1                  1         1.0
# 2                  2         2.0
# 3                  3         3.0
# 4                  4         4.0
# ...              ...         ...
# 117587          4995         NaN
# 117588          4996         NaN
# 117589          4997         NaN
# 117590          4998         NaN
# 117591          4999         NaN
#
#                                                     title  \
# 0                   Learning from compressed observations
# 1       Sensor Networks with Random Links: Topology De...
# 2       The on-line shortest path problem under partia...
# 3         A neural network approach to ordinal regression
# 4        Parametric Learning and Monte Carlo Optimization
# ...                                                   ...
# 117587  Detecting COVID-19 Conspiracy Theories with Tr...
# 117588  Fair Feature Subset Selection using Multiobjec...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'title', 'abstract'], dtype='object')

# %%
df=df[['title','abstract']]

# %%
df
# Out:
#                                                     title  \
# 0                   Learning from compressed observations
# 1       Sensor Networks with Random Links: Topology De...
# 2       The on-line shortest path problem under partia...
# 3         A neural network approach to ordinal regression
# 4        Parametric Learning and Monte Carlo Optimization
# ...                                                   ...
# 117587  Detecting COVID-19 Conspiracy Theories with Tr...
# 117588  Fair Feature Subset Selection using Multiobjec...
# 117589  A Simple Duality Proof for Wasserstein Distrib...
# 117590  Combined Learning of Neural Network Weights fo...
# 117591  Adapting and Evaluating Influence-Estimation M...
#
#                                                  abstract
# 0         The problem of statistical learning is to co...
# 1         In a sensor network, in practice, the commun...
# 2         The on-line shortest path problem is conside...
# ...

# %%
df.shape
# Out:
# (117592, 2)

# %%
df=df.head(15000)

# %%
df.shape
# Out:
# (15000, 2)

# %%
df.isnull().sum()
# Out:
# title       0
# abstract    0
# dtype: int64

# %%
df["paper_text"]=df["title"]+" "+df["abstract"]
# Out:
# /tmp/ipykernel_11682/1555653241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["paper_text"]=df["title"]+" "+df["abstract"]

# %%
type(df[["paper_text"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
df[["paper_text"]].head()
# Out:
#                                           paper_text
# 0  Learning from compressed observations   The pr...
# 1  Sensor Networks with Random Links: Topology De...
# 2  The on-line shortest path problem under partia...
# 3  A neural network approach to ordinal regressio...
# 4  Parametric Learning and Monte Carlo Optimizati...

# %%
print(df["paper_text"].iloc[0])
# Out:
# Learning from compressed observations   The problem of statistical learning is to construct a predictor of a random
# variable $Y$ as a function of a related random variable $X$ on the basis of an
# i.i.d. training sample from the joint distribution of $(X,Y)$. Allowable
# predictors are drawn from some specified class, and the goal is to approach
# asymptotically the performance (expected loss) of the best predictor in the
# class. We consider the setting in which one has perfect observation of the
# $X$-part of the sample, while the $Y$-part has to be communicated at some
# finite bit rate. The encoding of the $Y$-values is allowed to depend on the
# $X$-values. Under suitable regularity conditions on the admissible predictors,
# the underlying family of probability distributions and the loss function, we
# give an information-theoretic characterization of achievable predictor
# performance in terms of conditional distortion-rate functions. The ideas are
# ...

# %%
from sentence_transformers import SentenceTransformer
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
print(type(model))
# Out:
# <class 'sentence_transformers.sentence_transformer.model.SentenceTransformer'>

# %%
df["paper_text"]=df["paper_text"].str.replace("\n"," ",regex=False)
df["paper_text"]=df["paper_text"].str.strip()
# Out:
# /tmp/ipykernel_11682/3727444676.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["paper_text"]=df["paper_text"].str.replace("\n"," ",regex=False)
# /tmp/ipykernel_11682/3727444676.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["paper_text"]=df["paper_text"].str.strip()

# %%
sample_text=df["paper_text"].iloc[0]
sample_text
# Out:
# 'Learning from compressed observations   The problem of statistical learning is to construct a predictor of a random variable $Y$ as a function of a related random variable $X$ on the basis of an i.i.d. training sample from the joint distribution of $(X,Y)$. Allowable predictors are drawn from some specified class, and the goal is to approach asymptotically the performance (expected loss) of the best predictor in the class. We consider the setting in which one has perfect observation of the $X$-part of the sample, while the $Y$-part has to be communicated at some finite bit rate. The encoding of the $Y$-values is allowed to depend on the $X$-values. Under suitable regularity conditions on the admissible predictors, the underlying family of probability distributions and the loss function, we give an information-theoretic characterization of achievable predictor performance in terms of conditional distortion-rate functions. The ideas are illustrated on the example of nonparametric regr
# ...

# %%
embedding=model.encode(sample_text)
print(type(embedding))
print(embedding.shape)
# Out:
# <class 'numpy.ndarray'>
# (384,)

# %%
embedding[:56]
# Out:
# array([-0.1315641 , -0.00678266, -0.00367612,  0.03265158,  0.11219642,
#         0.01227267,  0.09816719, -0.0900523 ,  0.04231161, -0.01977348,
#        -0.03308417,  0.07452948,  0.10632038, -0.02060429, -0.02052106,
#         0.00169493,  0.07081953,  0.05854454, -0.11231912,  0.02082474,
#         0.05692544,  0.0201578 ,  0.0258311 ,  0.0321703 ,  0.10513764,
#        -0.09676763,  0.02700802, -0.0234509 , -0.04549678, -0.01013699,
#        -0.01794855, -0.04814427,  0.01077652, -0.03759069,  0.01943481,
#         0.03715189,  0.02967844,  0.04330941,  0.04373213,  0.03704866,
#        -0.00182594,  0.00455183, -0.00799067,  0.03037368, -0.014378  ,
#         0.03795147,  0.0595916 , -0.02583356, -0.06521576,  0.05900268,
#        -0.02107134,  0.07359422, -0.05720106,  0.00294061,  0.00767515,
#        -0.0333416 ], dtype=float32)

# %%
sample_embedding=model.encode(df["paper_text"]. head(5). to_list())

# %%
print(sample_embedding.shape)
# Out:
# (5, 384)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(sample_embedding[0].reshape(1, -1),sample_embedding[0].reshape(1, -1))
print(similarity)
# Out:
# [[1.0000001]]

# %%
similarity=cosine_similarity(sample_embedding[0].reshape(1, -1),sample_embedding[1].reshape(1, -1))
print(similarity)
# Out:
# [[0.36625272]]

# %%
for i in range(1,5):
  sim=cosine_similarity(sample_embedding[0].reshape(1, -1),sample_embedding[i].reshape(1, -1))
  print(sim)
# Out:
# [[0.36625272]]
# [[0.33522844]]
# [[0.15505108]]
# [[0.37421533]]

# %% [markdown]
# **Generating full Embedding**

# %%
import os
import numpy as np
if os.path.exists("paper_embeddings.npy"):
    print("Loading saved embeddings")
    embeddings = np.load("paper_embeddings.npy")
else:
    print("Generating embeddings")
    embeddings = model.encode(
        df["paper_text"].tolist(),
        batch_size=32,
        show_progress_bar=True
    )
    np.save("paper_embeddings.npy", embeddings)
    print("Embeddings saved successfully!")
# Out:
# Loading saved embeddings

# %%
import numpy as np

# %%
embedding = np.load("paper_embeddings.npy")
print("Embeddings loaded from paper_embeddings.npy (assuming manual upload)")
# Out:
# Embeddings loaded from paper_embeddings.npy (assuming manual upload)

# %%
print (embedding. shape)
print(type(embedding))
# Out:
# (15000, 384)
# <class 'numpy.ndarray'>

# %%
embedding.dtype
# Out:
# dtype('float32')

# %%
# !pip install faiss-cpu

# %%
import faiss

# %%
if os.path.exists("paper_faiss.index"):
    print("Loading existing FAISS index")
    index = faiss.read_index("paper_faiss.index")
else:
    print("Creating new FAISS index")
    faiss.normalize_L2(embeddings)
    index = faiss.IndexFlatIP(384)
    index.add(embeddings)
    faiss.write_index(index, "paper_faiss.index")
    print("FAISS index saved successfully!")
# Out:
# Loading existing FAISS index

# %%
faiss.normalize_L2(embedding)

# %%
index=faiss.IndexFlatIP(384)

# %%
index.add(embedding)

# %%
print(index.ntotal)
# Out:
# 15000

# %%
query="deep learning for medical iimage analysis"
query_embedding=model.encode([query])
query_embedding.shape
# Out:
# (1, 384)

# %%
faiss.normalize_L2(query_embedding)

# %%
D,I=index.search(query_embedding,5)
print(D)
print(I)
# Out:
# [[0.64207685 0.6242434  0.59919417 0.5965551  0.5874529 ]]
# [[13730 10466 12691 13212 14410]]

# %%
print(df.shape)
# Out:
# (15000, 3)

# %%
print(df["title"].head())
# Out:
# 0                Learning from compressed observations
# 1    Sensor Networks with Random Links: Topology De...
# 2    The on-line shortest path problem under partia...
# 3      A neural network approach to ordinal regression
# 4     Parametric Learning and Monte Carlo Optimization
# Name: title, dtype: object

# %%
print(df["title"].str.contains("medical", case=False).sum())
# Out:
# 40

# %%
print(embedding.shape)
# Out:
# (15000, 384)

# %%
import numpy as np

# %%
print(np.linalg.norm(embedding[0]))
# Out:
# 1.0

# %%
print(df.iloc[10466]["title"])
# Out:
# A Perspective on Deep Imaging

# %%
print(df.iloc[10466]["abstract"])
# Out:
#   The combination of tomographic imaging and deep learning, or machine learning
# in general, promises to empower not only image analysis but also image
# reconstruction. The latter aspect is considered in this perspective article
# with an emphasis on medical imaging to develop a new generation of image
# reconstruction theories and techniques. This direction might lead to
# intelligent utilization of domain knowledge from big data, innovative
# approaches for image reconstruction, and superior performance in clinical and
# preclinical applications. To realize the full impact of machine learning on
# medical imaging, major challenges must be addressed.

# %%
import numpy as np
import faiss
faiss.write_index(index, "paper_faiss.index")
print("FAISS index saved to paper_faiss.index")
# Out:
# FAISS index saved to paper_faiss.index

# %%
np.save("paper_embeddings.npy", embedding)
print("Embeddings saved to paper_embeddings.npy")
# Out:
# Embeddings saved to paper_embeddings.npy

# %%
print(df.iloc[11873]["title"])
# Out:
# Classification of MRI data using Deep Learning and Gaussian
#   Process-based Model Selection

# %%
def search_paper(query,k=5):
  query_embedding=model.encode([query])
  faiss.normalize_L2(query_embedding)
  D,I=index.search(query_embedding,k)
  return D,I

# %%
D,I= search_paper("deep learning for medical image analysis")
print(D)
print(I)
# Out:
# [[0.6807244  0.67092204 0.65219975 0.62811744 0.61311525]]
# [[10466 13730 11873 12691 11282]]

# %%
def search_paper(query,k=5):
  query_embedding=model.encode([query])
  faiss.normalize_L2(query_embedding)
  D,I=index.search(query_embedding,k)
  for score,idx in zip(D[0],I[0]):
    print("Similarity score",score)
    print("Title",df.iloc[idx]["title"])
    print("Title",df.iloc[idx]["abstract"][:500])
    print()

# %%
search_paper("deep learning for medical image analysis")
# Out:
# Similarity score 0.6807244
# Title A Perspective on Deep Imaging
# Title   The combination of tomographic imaging and deep learning, or machine learning
# in general, promises to empower not only image analysis but also image
# reconstruction. The latter aspect is considered in this perspective article
# with an emphasis on medical imaging to develop a new generation of image
# reconstruction theories and techniques. This direction might lead to
# intelligent utilization of domain knowledge from big data, innovative
# approaches for image reconstruction, and superior performance
#
# Similarity score 0.67092204
# Title Convolutional Neural Networks for Medical Image Analysis: Full Training
#   or Fine Tuning?
# Title   Training a deep convolutional neural network (CNN) from scratch is difficult
# because it requires a large amount of labeled training data and a great deal of
# expertise to ensure proper convergence. A promising alternative is to fine-tune
# ...

# %%
# !pip install transformers==4.46.3

# %%
from transformers import pipeline
summarizer=pipeline("summarization",model="facebook/bart-large-cnn")

# If you encountered an ImportError here, please try restarting the Colab runtime (Runtime -> Restart runtime)
# after ensuring `!pip install transformers==4.46.3` has run successfully.
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
type(summarizer)
# Out:
# transformers.pipelines.text2text_generation.SummarizationPipeline

# %%
summary=summarizer(df.iloc[10466]["abstract"], max_length=120,min_length=40)
print(summary)
# Out:
# [{'summary_text': 'The combination of tomographic imaging and deep learning, or machine learning, promises to empower not only image analysis but also image reconstructions. This direction might lead to intelligent utilization of domain knowledge from big data, innovativeapproaches for image reconstruction, and superior performance in clinical applications.'}]

# %%
type(summary)
# Out:
# list

# %%
type(summary[0])
# Out:
# dict

# %%
summary[0]["summary_text"]
# Out:
# 'The combination of tomographic imaging and deep learning, or machine learning, promises to empower not only image analysis but also image reconstructions. This direction might lead to intelligent utilization of domain knowledge from big data, innovativeapproaches for image reconstruction, and superior performance in clinical applications.'

# %%
for score,idx in zip(D[0],I[0]):
    print("Similarity score",score)
    print("Title",df.iloc[idx]["title"])
    print("Title",df.iloc[idx]["abstract"][:500])
    print()
    summary=summarizer(df.iloc[10466]["abstract"], max_length=120,min_length=40)
    print(summary)
    print(summary[0]["summary_text"])
    print()
# Out:
# Similarity score 0.6807244
# Title A Perspective on Deep Imaging
# Title   The combination of tomographic imaging and deep learning, or machine learning
# in general, promises to empower not only image analysis but also image
# reconstruction. The latter aspect is considered in this perspective article
# with an emphasis on medical imaging to develop a new generation of image
# reconstruction theories and techniques. This direction might lead to
# intelligent utilization of domain knowledge from big data, innovative
# approaches for image reconstruction, and superior performance
#
# [{'summary_text': 'The combination of tomographic imaging and deep learning, or machine learning, promises to empower not only image analysis but also image reconstructions. This direction might lead to intelligent utilization of domain knowledge from big data, innovativeapproaches for image reconstruction, and superior performance in clinical applications.'}]
# ...

# %%
def search_and_summarize(query,k=5):
  query_embedding=model.encode([query])
  faiss.normalize_L2(query_embedding)
  D,I=index.search(query_embedding,k)
  for score,idx in zip(D[0],I[0]):
    print("Similarity score",score)
    print("Title",df.iloc[idx]["title"])
    print("Title",df.iloc[idx]["abstract"][:500])
    print()

    summary=summarizer(df.iloc[idx]["abstract"],max_length=120,min_length=40,do_sample=False)
    print(summary)
    print(summary[0]["summary_text"])
    print()

# %%
search_and_summarize("Deep learning in medical imaging",k=5)
# Out:
# Similarity score 0.73549855
# Title A Perspective on Deep Imaging
# Title   The combination of tomographic imaging and deep learning, or machine learning
# in general, promises to empower not only image analysis but also image
# reconstruction. The latter aspect is considered in this perspective article
# with an emphasis on medical imaging to develop a new generation of image
# reconstruction theories and techniques. This direction might lead to
# intelligent utilization of domain knowledge from big data, innovative
# approaches for image reconstruction, and superior performance
#
# [{'summary_text': 'The combination of tomographic imaging and deep learning, or machine learning, promises to empower not only image analysis but also image reconstructions. This direction might lead to intelligent utilization of domain knowledge from big data, innovativeapproaches for image reconstruction, and superior performance in clinical applications.'}]
# ...

# %%
# !pip install keybert==0.8
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for keybert: filename=keybert-0.8.0-py3-none-any.whl size=39142 sha256=c94ec971bccdae33169d368b1e2a38769361c32148bc3942cd9c271c4e8a5d65
#   Stored in directory: /root/.cache/pip/wheels/8b/2c/b0/6a4586e1c5221cd77b28a8d38d741425bc69082234ff3bcc30
# Successfully built keybert
# ...

# %%
from keybert import KeyBERT

# %%
kw_model=KeyBERT(model)

# %%
type(kw_model)
# Out:
# keybert._model.KeyBERT

# %%
print(df.iloc[10466]["abstract"])
# Out:
#   The combination of tomographic imaging and deep learning, or machine learning
# in general, promises to empower not only image analysis but also image
# reconstruction. The latter aspect is considered in this perspective article
# with an emphasis on medical imaging to develop a new generation of image
# reconstruction theories and techniques. This direction might lead to
# intelligent utilization of domain knowledge from big data, innovative
# approaches for image reconstruction, and superior performance in clinical and
# preclinical applications. To realize the full impact of machine learning on
# medical imaging, major challenges must be addressed.

# %%
print(df.iloc[10466]["abstract"])
# Out:
#   The combination of tomographic imaging and deep learning, or machine learning
# in general, promises to empower not only image analysis but also image
# reconstruction. The latter aspect is considered in this perspective article
# with an emphasis on medical imaging to develop a new generation of image
# reconstruction theories and techniques. This direction might lead to
# intelligent utilization of domain knowledge from big data, innovative
# approaches for image reconstruction, and superior performance in clinical and
# preclinical applications. To realize the full impact of machine learning on
# medical imaging, major challenges must be addressed.

# %%
text=df.iloc[10466]["abstract"]
keywords = kw_model.extract_keywords(text)

# %%
print(keywords)
# Out:
# [('imaging', 0.4528), ('tomographic', 0.4488), ('reconstruction', 0.3623), ('deep', 0.3003), ('learning', 0.2622)]

# %%
print(type(keywords))
# Out:
# <class 'list'>

# %%
print(type(keywords[0]))
# Out:
# <class 'tuple'>

# %%
kw_model. extract_keywords(text, keyphrase_ngram_range= (1, 3), stop_words="english")
# Out:
# [('tomographic imaging deep', 0.6704),
#  ('imaging deep learning', 0.6543),
#  ('learning medical imaging', 0.6041),
#  ('imaging deep', 0.5919),
#  ('medical imaging', 0.5281)]

# %%
print(keywords)
# Out:
# [('imaging', 0.4528), ('tomographic', 0.4488), ('reconstruction', 0.3623), ('deep', 0.3003), ('learning', 0.2622)]

# %%
def search_and_summarize(query, k=5):
    query_embedding=model.encode([query])
    faiss.normalize_L2(query_embedding)
    D,I=index.search(query_embedding, k)
    for score, idx in zip (D[0],I[0]):
        print("Similarity score", score)
        print("Title", df.iloc[idx] ["title"])
        print("Title", df.iloc[idx] ["abstract"][:500])
        print()
        summary=summarizer(df.iloc[idx] ["abstract"], max_length=120,min_length=40, do_sample=False)
        print(summary)
        print(summary[0]["summary_text"])
        print()
        keywords = kw_model.extract_keywords(df.iloc[idx]["abstract"], keyphrase_ngram_range= (1, 3), stop_words="english")
        print(keywords)
        for k_word,s in keywords:
            print(k_word)

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 2.4 MB/s eta 0:00:00

# %%
from groq import Groq
import json

# %%
client = Groq(api_key="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")

# %%
def generate_paper_profile(title, abstract):

    prompt = f"""
You are an expert AI Research Assistant.

Analyze the research paper.

Return ONLY valid JSON.

{{
"Research Area":"",
"Method":"",
"Dataset":"",
"Task":"",
"Contribution":"",
"Difficulty":"",
"Best For":"",
"Estimated Reading Time":""
}}

Title:
{title}

Abstract:
{abstract}
"""

    completion = client.chat.completions.create(

        model="llama-3.3-70b-versatile",

        messages=[
            {
                "role":"user",
                "content":prompt
            }
        ],

        temperature=0.2

    )

    text = completion.choices[0].message.content

    text = text.replace("```json","").replace("```","").strip()

    return json.loads(text)

# %%
try:
    profile = json.loads(text)
except json.JSONDecodeError:
    profile = {
        "Research Area": "Not Mentioned",
        "Method": "Not Mentioned",
        "Dataset": "Not Mentioned",
        "Task": "Not Mentioned",
        "Contribution": text,
        "Difficulty": "Intermediate",
        "Best For": "Researchers",
        "Estimated Reading Time": "1 minute"
    }

# %%
def search_and_summarize(query, k=5):

    # ==========================
    # Query Embedding
    # ==========================

    query_embedding = model.encode([query])

    faiss.normalize_L2(query_embedding)

    scores, indices = index.search(query_embedding, k)

    print("\n")
    print("=" * 110)
    print("🔍 AI RESEARCH PAPER RECOMMENDATION SYSTEM")
    print("=" * 110)
    print(f"Search Query : {query}")
    print(f"Top {k} Recommended Papers")
    print("=" * 110)

    # ==========================
    # Loop over retrieved papers
    # ==========================

    for rank, (score, idx) in enumerate(zip(scores[0], indices[0]), start=1):

        title = df.iloc[idx]["title"]

        abstract = df.iloc[idx]["abstract"]

        print("\n")
        print("═" * 110)
        print(f" PAPER {rank}")
        print("═" * 110)

        print(f" Match Score : {score*100:.2f}%")

        print("\n TITLE")
        print("-" * 110)
        print(title)

        print("\n ABSTRACT PREVIEW")
        print("-" * 110)

        if len(abstract) > 350:

            print(abstract[:350] + "...")

        else:

            print(abstract)

        # =====================================
        # Generate Summary
        # =====================================

        summary = summarizer(

            abstract,

            max_length=120,

            min_length=40,

            do_sample=False

        )[0]["summary_text"]

        print("\n SUMMARY")
        print("-" * 110)

        print(summary)

        # =====================================
        # Extract Keywords
        # =====================================

        keywords = kw_model.extract_keywords(

            abstract,

            top_n=5,

            stop_words="english"

        )

        keyword_list = ", ".join([word for word, score in keywords])

        print("\n KEYWORDS")
        print("-" * 110)

        print(keyword_list)

        # =====================================
        # AI Research Paper Profile
        # =====================================

        profile = generate_paper_profile(

            title,

            abstract

        )

        print("\n RESEARCH PAPER PROFILE")

        print("-" * 110)

        print(f" Research Area           : {profile['Research Area']}")

        print(f" Method                 : {profile['Method']}")

        print(f" Dataset                : {profile['Dataset']}")

        print(f" Task                   : {profile['Task']}")

        print(f" Contribution           : {profile['Contribution']}")

        print(f" Difficulty             : {profile['Difficulty']}")

        print(f" Best For               : {profile['Best For']}")

        print(f" Estimated Reading Time  : {profile['Estimated Reading Time']}")

        print("═" * 110)

    print("\n")
    print("=" * 110)
    print("✅ Recommendation Completed")
    print("=" * 110)

# %%
def generate_paper_profile(title, abstract):

    prompt = f"""
You are an expert AI Research Assistant.

Analyze the following research paper and return ONLY valid JSON.

Rules:
1. Return exactly one value for each field.
2. If unavailable, return "Not Mentioned".
3. Contribution should be one sentence.
4. Difficulty must be Beginner, Intermediate or Advanced.

Return ONLY:

{{
    "Research Area":"",
    "Method":"",
    "Dataset":"",
    "Task":"",
    "Contribution":"",
    "Difficulty":"",
    "Best For":"",
    "Estimated Reading Time":""
}}

Title:
{title}

Abstract:
{abstract}
"""

    completion = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ],
        temperature=0.2
    )

    text = completion.choices[0].message.content.strip()

    if text.startswith("```"):
        text = text.replace("```json", "")
        text = text.replace("```", "")
        text = text.strip()

    profile = json.loads(text)

    return profile

# %%
import os

print(os.path.exists("paper_embeddings.npy"))
print(os.listdir("/content"))
# Out:
# True
# ['.config', 'paper_faiss.index', 'paper_embeddings.npy', 'sample_data']

# %% [markdown]
# text

# %%
search_and_summarize("Deep learning in medical imaging",k=2)
# Out:
# ...
# 🔍 AI RESEARCH PAPER RECOMMENDATION SYSTEM
# ...
# Search Query : Deep learning in medical imaging
# Top 2 Recommended Papers
# ...
#
#
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#  PAPER 1
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#  Match Score : 73.55%
#
#  TITLE
# --------------------------------------------------------------------------------------------------------------
# A Perspective on Deep Imaging
#
#  ABSTRACT PREVIEW
# --------------------------------------------------------------------------------------------------------------
#   The combination of tomographic imaging and deep learning, or machine learning
# in general, promises to empower not only image analysis but also image
# reconstruction. The latter aspect is considered in this perspective article
# with an emphasis on medical imaging to develop a new generation of image
# ...
